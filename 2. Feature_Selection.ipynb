# %% [markdown]
# ## The below script determines which features warrant retention for our models, due to the predictive value that they provide

# %% [markdown]
# ### Outline of notebook:
#
# #### 2.1 Formatting notebook environment and importing dataset
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Function: <u>CSV_Reader()</u><br>
# #### 2.2 Assessing feature correlations with patient readmissions
# #### 2.3 Assessing the feature importance via Random Forest
# #### 2.4 Assessing Akaike Information Criterion (AIC)
# #### 2.5 Assessing feature variability with Principal Component Analysis (PCA)
# #### 2.6 Exporting engineered datasets to S3 for machine learning
# &nbsp;&nbsp;&nbsp;&nbsp;Train/validation and test data subsets saved in csv<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Function: <u>Export_Processed_CSV()</u><br>

# %% [markdown]
# #### Purpose of Feature Selection
# There is an inherent trade-off between the the value that additional features brings to a predictive model, and the added computational effort that assessing this increased "dimensionality" of this data brings. As a massive amount of irrelevant data will not help with predictions, and the opportunity cost of time that is spent assessing this irrelevant data might otherwise be spent in identifying a different, elusive, and optimized model iteration.
#
# As such, this notebook conducts a series of tests to identify features that may not provide enough inherent predictive information to justify their continued inclusion. Such variables will be removed, and the resulting filtered dataset will be exported for machine learning.
#
# Techniques that assess both a feature's relationship with patient readmission, and the degree of inherent variability in contained within a feature, will be employed. A small number of the worst performers from each test will be removed, provided that there is no strong subjective/contextual reason for their retention.
#
# Feature selection involves both technical and subjective components, and as such it is not an exact science. Therefore it will not necessarily improve predictions, but offers the potential to do so. As prior testing indicated that there is some degree of overfitting in our deployed model (i.e. the model does not predict as well on unseen data as it did on it's validation data), examining whether dimensionality reduction will improve model performance represents proper due dilligence.
#
# Variations of a full, and different partial datasets were made. The below combination of retained features  yielded the best eventual models.

# %% [markdown]
# ## 2.1 Formatting notebook environment and importing dataset

# %% [markdown]
# #### We begin by importing the necessary libraries.

# %%
#pip install numexpr==2.8.0

# %%
#pip install --upgrade s3fs

# %% [markdown]
# #### Importing the necessary Libraries

# %%
#Data manipulation libraries
import pandas as pd
import numpy as np
import random as random
from sklearn.utils import shuffle

#Sagemaker and other AWS libraries
import sagemaker
import sagemaker.amazon.common as smac
import boto3
from sagemaker import get_execution_role
import os

#importing some basic machine learning libraries to test feature importance
from sklearn.ensemble import RandomForestClassifier as rfc
import statsmodels.api as sm
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

#Defining some variables for Sagemaker session
region = boto3.Session().region_name
smclient = boto3.Session().client('sagemaker')
role = get_execution_role()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# #### As this is a fairly large dataset, we will reformat the default display dimensions to reflect this.

# %%
#500 rows and columns will be presented
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# #### The below function will read in our dataset.

# %%
def CSV_Reader(bucket, subfolder, source_file_name):
    
    '''The CSV_Reader() function takes in the names of the bucket, subfolder, and source file name, and desired dataframe name. 
    It first constructs the filepath, and then imports the file residing at this filepath, based on the title fed to the function.
    
    Arguments 
    --------- 
    bucket: Head S3 repository bucket
    subfolder: Subfolder containing the source data
    source_file_name: Name of source CSV data file 
    
    Return
    ---------
    Returns the source data in a pandas dataframe '''
    
    data_location = 's3://{}/{}/{}'.format(bucket, subfolder, source_file_name)  
    dataset = pd.read_csv(data_location, low_memory=False)
    return dataset

# %% [markdown]
# #### Reading in the data from S3

# %%
bucket = 'diabetes-directory'
cleaned_diabetes = 'diabetes_processed_data'
input_file_name = 'prepared_diabetes.csv'
reduced_dimensions_diabetes_train = 'reduced_dimensions_diabetes_train.csv'
reduced_dimensions_diabetes_test = 'reduced_dimensions_diabetes_test.csv'

# %% [markdown]
# #### Reading our data and confirming it looks as expected

# %%
diabetes = CSV_Reader(bucket, cleaned_diabetes, input_file_name)

# %%
print(diabetes.shape)

diabetes.sample(5)
# Out:
# (100114, 98)
#        readmitted  time_in_hospital  num_lab_procedures  num_procedures  \
# 88590           0                 4                  45               2
# 45941           1                 1                  44               0
# 71495           0                 4                  49               1
# 59151           0                 4                  38               2
# 18804           0                 6                  59               0
#
#        num_medications  number_outpatient  number_emergency  number_inpatient  \
# 88590               21                  0                 0                 0
# 45941                7                  0                 0                 0
# 71495               17                  0                 0                 0
# 59151                1                  0                 0                 0
# 18804               19                  0                 0                 0
#
#        number_diagnoses  medication_metformin  medication_glipizide  \
# 88590                 8                     0                     1
# 45941                 5                     0                     1
# 71495                 6                     0                     0
# 59151                 7                     0                     0
# 18804                 9                     0                     0
#
#        medication_glyburide  medication_insulin  change  any_medication  \
# 88590                     0                   0       0               1
# 45941                     0                   1       1               1
# 71495                     0                   1       0               1
# 59151                     0                   0       0               0
# 18804                     0                   1       1               1
#
#        race_AfricanAmerican  race_Asian  race_Hispanic  race_Other  age_1  \
# 88590                     0           0              0           0      0
# 45941                     0           0              0           0      0
# 71495                     1           0              0           0      0
# 59151                     0           0              0           0      0
# 18804                     0           0              0           0      0
#
#        age_2  age_3  age_4  age_5  age_6  age_7  age_9  age_10  gender_Male  \
# 88590      0      0      0      0      0      0      1       0            0
# 45941      0      0      0      1      0      0      0       0            0
# 71495      0      0      0      0      0      1      0       0            0
# 59151      0      0      0      0      0      0      1       0            1
# 18804      0      0      0      0      0      0      1       0            0
#
#        discharge_disposition_hhealth  discharge_disposition_hospice  \
# 88590                              0                              0
# 45941                              0                              0
# 71495                              0                              0
# 59151                              0                              0
# 18804                              0                              0
#
#        discharge_disposition_hospital  discharge_disposition_leftAMA  \
# 88590                               0                              0
# 45941                               0                              0
# 71495                               0                              0
# 59151                               0                              0
# 18804                               0                              0
#
#        discharge_disposition_nursing  discharge_disposition_outpatient  \
# 88590                              0                                 0
# 45941                              0                                 0
# 71495                              1                                 0
# 59151                              0                                 0
# 18804                              1                                 0
#
#        discharge_disposition_psych  discharge_disposition_unknown  \
# 88590                            0                              0
# 45941                            0                              0
# 71495                            0                              0
# 59151                            0                              0
# 18804                            0                              0
#
#        diag_1_Nothing  diag_1_blooddis  diag_1_digestive  diag_1_infection  \
# 88590               0                0                 0                 0
# 45941               0                0                 0                 0
# 71495               0                0                 0                 0
# 59151               0                0                 0                 0
# 18804               1                0                 0                 0
#
#        diag_1_injury  diag_1_mentaldis  diag_1_metabolic  \
# 88590              0                 0                 0
# 45941              1                 0                 0
# 71495              0                 0                 0
# 59151              0                 0                 0
# 18804              0                 0                 0
#
#        diag_1_musculoskeletal  diag_1_neoplasm  diag_1_nervous  diag_1_other  \
# 88590                       0                0               0             0
# 45941                       0                0               0             0
# 71495                       1                0               0             0
# 59151                       0                0               0             0
# 18804                       0                0               0             0
#
#        diag_1_pregnancy  diag_1_respiratory  diag_1_skin  diag_1_urogenital  \
# 88590                 0                   0            0                  0
# 45941                 0                   0            0                  0
# 71495                 0                   0            0                  0
# 59151                 0                   0            0                  0
# 18804                 0                   0            0                  0
#
#        diag_2_Nothing  diag_2_blooddis  diag_2_digestive  diag_2_infection  \
# 88590               0                0                 0                 0
# 45941               0                0                 0                 0
# 71495               0                0                 0                 0
# 59151               0                0                 0                 0
# 18804               0                0                 0                 0
#
#        diag_2_injury  diag_2_mentaldis  diag_2_metabolic  \
# 88590              0                 0                 0
# 45941              0                 0                 0
# 71495              0                 0                 0
# 59151              0                 0                 0
# 18804              0                 0                 1
#
#        diag_2_musculoskeletal  diag_2_neoplasm  diag_2_nervous  diag_2_other  \
# 88590                       0                0               0             0
# 45941                       0                0               0             0
# 71495                       0                0               0             1
# 59151                       0                0               0             0
# 18804                       0                0               0             0
#
#        diag_2_pregnancy  diag_2_respiratory  diag_2_skin  diag_2_urogenital  \
# 88590                 0                   0            0                  0
# 45941                 0                   1            0                  0
# 71495                 0                   0            0                  0
# 59151                 0                   0            0                  0
# 18804                 0                   0            0                  0
#
#        diag_3_Nothing  diag_3_blooddis  diag_3_digestive  diag_3_infection  \
# 88590               1                0                 0                 0
# 45941               0                0                 0                 0
# 71495               0                0                 1                 0
# 59151               0                0                 0                 0
# 18804               0                0                 0                 0
#
#        diag_3_injury  diag_3_mentaldis  diag_3_metabolic  \
# 88590              0                 0                 0
# 45941              0                 0                 0
# 71495              0                 0                 0
# 59151              0                 0                 0
# 18804              0                 0                 0
#
#        diag_3_musculoskeletal  diag_3_neoplasm  diag_3_nervous  diag_3_other  \
# 88590                       0                0               0             0
# 45941                       0                0               0             0
# 71495                       0                0               0             0
# 59151                       0                0               0             0
# 18804                       0                0               0             0
#
#        diag_3_pregnancy  diag_3_respiratory  diag_3_skin  diag_3_urogenital  \
# 88590                 0                   0            0                  0
# 45941                 0                   0            0                  0
# 71495                 0                   0            0                  0
# 59151                 0                   0            0                  0
# 18804                 0                   0            1                  0
#
#        max_glu_serum_>200  max_glu_serum_>300  A1Cresult_>7  A1Cresult_Norm  \
# 88590                   0                   0             0               0
# 45941                   0                   0             0               0
# 71495                   0                   0             0               1
# 59151                   0                   0             0               0
# 18804                   0                   0             0               0
#
#        admission_type_id_2  admission_type_id_3  admission_type_id_4  \
# 88590                    0                    0                    0
# 45941                    0                    0                    0
# 71495                    0                    1                    0
# 59151                    0                    0                    0
# 18804                    0                    0                    0
#
#        admission_type_id_5  admission_type_id_7  admission_source_id_1  \
# 88590                    0                    0                      0
# 45941                    0                    0                      0
# 71495                    0                    0                      1
# 59151                    0                    0                      0
# 18804                    0                    0                      0
#
#        admission_source_id_2  admission_source_id_3  admission_source_id_4  \
# 88590                      0                      0                      0
# 45941                      0                      0                      0
# 71495                      0                      0                      0
# 59151                      0                      0                      0
# 18804                      0                      0                      0
#
#        admission_source_id_5  admission_source_id_6  admission_source_id_8
# 88590                      0                      0                      0
# 45941                      0                      0                      0
# 71495                      0                      0                      0
# 59151                      0                      0                      0
# 18804                      0                      0                      0

# %% [markdown]
# #### We extract the train/validation dataset, and remove the column which recorded this designation

# %%
X = diabetes.drop(columns=['readmitted'])  # Remove the outcome column
y = diabetes['readmitted']

# %% [markdown]
# ## 2.2 Assessing feature correlations with patient readmissions

# %% [markdown]
# Below we fit a basic linear correlation between each individual feature and patient readmission. We take the absolute value, as we are interested in the magnitude, not direction, of these correlations.

# %%
correlations = X.corrwith(y).abs().sort_values(ascending=False).reset_index()

#We rename the columns of our correlation-value-dataset for interpretability.
correlations.columns = ['feature', 'correlation with outcome']

# %%
#Our retained variables
correlations
# Out:
#                              feature  correlation with outcome
# 0                   number_inpatient                  0.167589
# 1   discharge_disposition_outpatient                  0.072407
# 2                   number_emergency                  0.060787
# 3                   number_diagnoses                  0.052343
# 4                   time_in_hospital                  0.045530
# 5      discharge_disposition_nursing                  0.042177
# 6                    num_medications                  0.040725
# 7                 medication_insulin                  0.034057
# 8        discharge_disposition_psych                  0.029802
# 9                     any_medication                  0.025910
# 10              medication_metformin                  0.025118
# 11                num_lab_procedures                  0.023385
# 12                             age_6                  0.022769
# 13    discharge_disposition_hospital                  0.022105
# 14                   diag_2_neoplasm                  0.020753
# 15                 diag_3_urogenital                  0.020168
# 16                 number_outpatient                  0.019097
# 17                            change                  0.018283
# 18                diag_1_respiratory                  0.017540
# 19                     diag_1_injury                  0.017325
# 20                    diag_1_Nothing                  0.017148
# 21     discharge_disposition_hhealth                  0.016593
# 22     discharge_disposition_hospice                  0.015529
# 23                             age_9                  0.015447
# 24                    diag_3_Nothing                  0.015334
# 25                   diag_3_neoplasm                  0.015013
# 26                        race_Other                  0.014905
# 27                  diag_2_pregnancy                  0.014745
# 28                             age_2                  0.014571
# 29                  diag_1_pregnancy                  0.013710
# 30                  diag_3_pregnancy                  0.013658
# 31             admission_source_id_1                  0.013587
# 32               admission_type_id_3                  0.013305
# 33                       diag_2_skin                  0.013285
# 34            diag_1_musculoskeletal                  0.012854
# 35                max_glu_serum_>300                  0.012569
# 36                       diag_3_skin                  0.012240
# 37                             age_3                  0.012078
# 38                             age_1                  0.011946
# 39                    A1Cresult_Norm                  0.011416
# 40                    num_procedures                  0.010485
# 41                diag_3_respiratory                  0.010067
# 42                    diag_2_Nothing                  0.009421
# 43             admission_source_id_6                  0.009056
# 44                  diag_3_metabolic                  0.008971
# 45                   diag_2_blooddis                  0.008792
# 46             admission_source_id_4                  0.008376
# 47     discharge_disposition_leftAMA                  0.007741
# 48                      A1Cresult_>7                  0.007640
# 49                       diag_1_skin                  0.007451
# 50                   diag_1_blooddis                  0.007202
# 51                             age_5                  0.006943
# 52              medication_glyburide                  0.006840
# 53                      diag_3_other                  0.006392
# 54            diag_2_musculoskeletal                  0.005890
# 55             admission_source_id_3                  0.005877
# 56                 diag_2_urogenital                  0.005727
# 57                max_glu_serum_>200                  0.005726
# 58             admission_source_id_8                  0.005667
# 59                      diag_1_other                  0.005580
# 60               admission_type_id_5                  0.005540
# 61                  diag_1_digestive                  0.005364
# 62                     diag_3_injury                  0.005243
# 63                  diag_3_digestive                  0.004987
# 64                   diag_1_neoplasm                  0.004983
# 65                  diag_1_metabolic                  0.004873
# 66               admission_type_id_7                  0.004797
# 67                diag_2_respiratory                  0.004719
# 68                  diag_1_infection                  0.004718
# 69                  diag_2_infection                  0.004677
# 70                  diag_1_mentaldis                  0.004186
# 71                     race_Hispanic                  0.003940
# 72             admission_source_id_2                  0.003610
# 73             admission_source_id_5                  0.003037
# 74     discharge_disposition_unknown                  0.002999
# 75                        race_Asian                  0.002662
# 76                       gender_Male                  0.002630
# 77                 diag_1_urogenital                  0.002573
# 78                    diag_3_nervous                  0.002345
# 79            diag_3_musculoskeletal                  0.002252
# 80                  diag_2_mentaldis                  0.002236
# 81              medication_glipizide                  0.002096
# 82                  diag_2_digestive                  0.002069
# 83                    diag_2_nervous                  0.001638
# 84                            age_10                  0.001435
# 85                   diag_3_blooddis                  0.001364
# 86                             age_7                  0.001113
# 87                      diag_2_other                  0.001041
# 88              race_AfricanAmerican                  0.000993
# 89                  diag_3_mentaldis                  0.000638
# 90                             age_4                  0.000514
# 91               admission_type_id_4                  0.000424
# 92                  diag_3_infection                  0.000229
# 93                     diag_2_injury                  0.000226
# 94                    diag_1_nervous                  0.000220
# 95                  diag_2_metabolic                  0.000136
# 96               admission_type_id_2                  0.000128

# %% [markdown]
# The bottom 20 or so vairables on this list do not demonstrate raise any contextual red flags (i.e. I cannot think of any reason why they would be of particular predictive/other value). As so, they will be removed.
#
# To filter down our ~100 variables to only those that correlate with patient readmission (and thereby reduce our dataset's dimensionality by only computing/focusing on relevant data) we will remove features the features representing the bottom 20% of our feature-correlation-values.

# %%
correlations_keep = correlations['feature'].head(int(len(diabetes.columns) * 80 / 100))
print(len(correlations_keep))
# Out:
# 78

# %%
corr_dataset = diabetes[correlations_keep]

print(corr_dataset.shape)
corr_dataset.sample(3)
# Out:
# (100114, 78)
#        number_inpatient  discharge_disposition_outpatient  number_emergency  \
# 80870                 1                                 0                 0
# 86104                 0                                 0                 0
# 57752                 0                                 0                 0
#
#        number_diagnoses  time_in_hospital  discharge_disposition_nursing  \
# 80870                 9                 5                              0
# 86104                 8                 3                              0
# 57752                 5                 6                              1
#
#        num_medications  medication_insulin  discharge_disposition_psych  \
# 80870               21                   0                            0
# 86104               28                   0                            0
# 57752               18                   0                            0
#
#        any_medication  medication_metformin  num_lab_procedures  age_6  \
# 80870               1                     0                  69      0
# 86104               1                     1                  32      1
# 57752               1                     0                   1      0
#
#        discharge_disposition_hospital  diag_2_neoplasm  diag_3_urogenital  \
# 80870                               0                0                  0
# 86104                               0                0                  0
# 57752                               0                0                  0
#
#        number_outpatient  change  diag_1_respiratory  diag_1_injury  \
# 80870                  0       0                   1              0
# 86104                  2       0                   0              0
# 57752                  0       0                   1              0
#
#        diag_1_Nothing  discharge_disposition_hhealth  \
# 80870               0                              0
# 86104               0                              0
# 57752               0                              0
#
#        discharge_disposition_hospice  age_9  diag_3_Nothing  diag_3_neoplasm  \
# 80870                              0      0               0                0
# 86104                              0      0               0                0
# 57752                              0      0               0                0
#
#        race_Other  diag_2_pregnancy  age_2  diag_1_pregnancy  \
# 80870           0                 0      0                 0
# 86104           0                 0      0                 0
# 57752           0                 0      0                 0
#
#        diag_3_pregnancy  admission_source_id_1  admission_type_id_3  \
# 80870                 0                      0                    0
# 86104                 0                      1                    1
# 57752                 0                      0                    0
#
#        diag_2_skin  diag_1_musculoskeletal  max_glu_serum_>300  diag_3_skin  \
# 80870            0                       0                   0            0
# 86104            0                       1                   0            0
# 57752            0                       0                   0            1
#
#        age_3  age_1  A1Cresult_Norm  num_procedures  diag_3_respiratory  \
# 80870      0      0               0               0                   1
# 86104      0      0               0               1                   0
# 57752      0      0               0               2                   0
#
#        diag_2_Nothing  admission_source_id_6  diag_3_metabolic  \
# 80870               0                      0                 0
# 86104               0                      0                 0
# 57752               0                      0                 0
#
#        diag_2_blooddis  admission_source_id_4  discharge_disposition_leftAMA  \
# 80870                0                      0                              0
# 86104                0                      0                              0
# 57752                0                      0                              0
#
#        A1Cresult_>7  diag_1_skin  diag_1_blooddis  age_5  \
# 80870             0            0                0      0
# 86104             0            0                0      0
# 57752             0            0                0      0
#
#        medication_glyburide  diag_3_other  diag_2_musculoskeletal  \
# 80870                     0             0                       0
# 86104                     0             0                       0
# 57752                     0             0                       0
#
#        admission_source_id_3  diag_2_urogenital  max_glu_serum_>200  \
# 80870                      0                  0                   0
# 86104                      0                  0                   0
# 57752                      0                  0                   0
#
#        admission_source_id_8  diag_1_other  admission_type_id_5  \
# 80870                      0             0                    0
# 86104                      0             0                    0
# 57752                      0             0                    0
#
#        diag_1_digestive  diag_3_injury  diag_3_digestive  diag_1_neoplasm  \
# 80870                 0              0                 0                0
# 86104                 0              1                 0                0
# 57752                 0              0                 0                0
#
#        diag_1_metabolic  admission_type_id_7  diag_2_respiratory  \
# 80870                 0                    0                   0
# 86104                 0                    0                   1
# 57752                 0                    0                   0
#
#        diag_1_infection  diag_2_infection  diag_1_mentaldis  race_Hispanic  \
# 80870                 0                 0                 0              0
# 86104                 0                 0                 0              0
# 57752                 0                 0                 0              0
#
#        admission_source_id_2  admission_source_id_5  \
# 80870                      0                      0
# 86104                      0                      0
# 57752                      0                      0
#
#        discharge_disposition_unknown  race_Asian  gender_Male  \
# 80870                              0           0            1
# 86104                              0           0            1
# 57752                              0           0            1
#
#        diag_1_urogenital
# 80870                  0
# 86104                  0
# 57752                  0

# %% [markdown]
# ## 2.3 Assessing the feature importance via Random Forest

# %% [markdown]
# Similar to our above linear correlation values, by running a basic random forest on the remaining varaibles we can determine the relative degree to which they influence predictions.

# %%
#We are able to call this model in from sklearn, and do not need to call a model container.
rfc = rfc()
rfc.set_params(n_estimators=200, min_samples_split=5, min_samples_leaf=1, max_features='sqrt', max_depth=60)

#Fits a random forest on the dataset for the purpose of feature importance:
rfc.fit(corr_dataset, y)
# Out:
# RandomForestClassifier(max_depth=60, min_samples_split=5, n_estimators=200)

# %% [markdown]
# #### Now we can list out the importance of each feature:

# %%
FIAllDummyAllFeatures = pd.DataFrame({'feature':pd.Series(corr_dataset.columns), 'importance':rfc.feature_importances_})

FIAllDummyAllFeatures = FIAllDummyAllFeatures.sort_values('importance', ascending=False)
FIAllDummyAllFeatures
# Out:
#                              feature  importance
# 11                num_lab_procedures    0.115860
# 6                    num_medications    0.098327
# 4                   time_in_hospital    0.066531
# 0                   number_inpatient    0.061482
# 40                    num_procedures    0.046642
# 3                   number_diagnoses    0.041968
# 16                 number_outpatient    0.025310
# 2                   number_emergency    0.022625
# 76                       gender_Male    0.020530
# 31             admission_source_id_1    0.016047
# 17                            change    0.016023
# 24                    diag_3_Nothing    0.014440
# 23                             age_9    0.014150
# 42                    diag_2_Nothing    0.012879
# 7                 medication_insulin    0.012516
# 67                diag_2_respiratory    0.012484
# 32               admission_type_id_3    0.012013
# 56                 diag_2_urogenital    0.011729
# 12                             age_6    0.011694
# 52              medication_glyburide    0.011617
# 41                diag_3_respiratory    0.011536
# 44                  diag_3_metabolic    0.011419
# 10              medication_metformin    0.011371
# 21     discharge_disposition_hhealth    0.011195
# 61                  diag_1_digestive    0.010994
# 18                diag_1_respiratory    0.010929
# 19                     diag_1_injury    0.010712
# 51                             age_5    0.010690
# 1   discharge_disposition_outpatient    0.010240
# 15                 diag_3_urogenital    0.010088
# 5      discharge_disposition_nursing    0.009921
# 60               admission_type_id_5    0.009877
# 62                     diag_3_injury    0.009843
# 20                    diag_1_Nothing    0.009296
# 9                     any_medication    0.008742
# 77                 diag_1_urogenital    0.008382
# 39                    A1Cresult_Norm    0.007958
# 63                  diag_3_digestive    0.007798
# 74     discharge_disposition_unknown    0.007510
# 48                      A1Cresult_>7    0.007263
# 33                       diag_2_skin    0.007220
# 58             admission_source_id_8    0.007070
# 53                      diag_3_other    0.007049
# 13    discharge_disposition_hospital    0.006750
# 26                        race_Other    0.006581
# 65                  diag_1_metabolic    0.006335
# 59                      diag_1_other    0.006300
# 36                       diag_3_skin    0.006290
# 68                  diag_1_infection    0.006139
# 34            diag_1_musculoskeletal    0.006010
# 14                   diag_2_neoplasm    0.005851
# 64                   diag_1_neoplasm    0.005847
# 46             admission_source_id_4    0.005565
# 22     discharge_disposition_hospice    0.005548
# 45                   diag_2_blooddis    0.005494
# 70                  diag_1_mentaldis    0.005479
# 69                  diag_2_infection    0.005301
# 49                       diag_1_skin    0.005240
# 71                     race_Hispanic    0.005136
# 25                   diag_3_neoplasm    0.004952
# 54            diag_2_musculoskeletal    0.004250
# 50                   diag_1_blooddis    0.003880
# 43             admission_source_id_6    0.003863
# 37                             age_3    0.003438
# 35                max_glu_serum_>300    0.003372
# 57                max_glu_serum_>200    0.003208
# 72             admission_source_id_2    0.002995
# 73             admission_source_id_5    0.002800
# 47     discharge_disposition_leftAMA    0.002657
# 8        discharge_disposition_psych    0.002558
# 75                        race_Asian    0.002379
# 55             admission_source_id_3    0.001317
# 28                             age_2    0.000874
# 29                  diag_1_pregnancy    0.000767
# 27                  diag_2_pregnancy    0.000407
# 30                  diag_3_pregnancy    0.000303
# 38                             age_1    0.000134
# 66               admission_type_id_7    0.000012

# %% [markdown]
# #### As there are not any variables within the bottom 10-15 of this feature importance list, we will remove those among the lowest 15% of feature importance values.

# %%
FI_keep = FIAllDummyAllFeatures['feature'].head(int(len(FIAllDummyAllFeatures) * 85 / 100))
print(len(FI_keep))
# Out:
# 66

# %%
FI_dataset = corr_dataset[FI_keep]

print(FI_dataset.shape)
FI_dataset.sample(3)
# Out:
# (100114, 66)
#        num_lab_procedures  num_medications  time_in_hospital  \
# 59249                   1               11                 2
# 78837                  54               14                 2
# 53312                  28               11                 3
#
#        number_inpatient  num_procedures  number_diagnoses  number_outpatient  \
# 59249                 0               3                 9                  0
# 78837                 0               0                 4                  0
# 53312                 0               1                 9                  0
#
#        number_emergency  gender_Male  admission_source_id_1  change  \
# 59249                 0            1                      1       0
# 78837                 0            1                      0       1
# 53312                 0            1                      0       1
#
#        diag_3_Nothing  age_9  diag_2_Nothing  medication_insulin  \
# 59249               0      1               0                   0
# 78837               0      0               0                   1
# 53312               0      0               0                   0
#
#        diag_2_respiratory  admission_type_id_3  diag_2_urogenital  age_6  \
# 59249                   0                    1                  0      0
# 78837                   0                    0                  0      0
# 53312                   1                    1                  0      0
#
#        medication_glyburide  diag_3_respiratory  diag_3_metabolic  \
# 59249                     0                   0                 0
# 78837                     1                   0                 0
# 53312                     0                   0                 0
#
#        medication_metformin  discharge_disposition_hhealth  diag_1_digestive  \
# 59249                     0                              0                 0
# 78837                     1                              0                 0
# 53312                     0                              0                 0
#
#        diag_1_respiratory  diag_1_injury  age_5  \
# 59249                   0              0      0
# 78837                   0              0      0
# 53312                   0              0      0
#
#        discharge_disposition_outpatient  diag_3_urogenital  \
# 59249                                 0                  1
# 78837                                 0                  0
# 53312                                 0                  0
#
#        discharge_disposition_nursing  admission_type_id_5  diag_3_injury  \
# 59249                              0                    0              0
# 78837                              0                    0              1
# 53312                              0                    0              0
#
#        diag_1_Nothing  any_medication  diag_1_urogenital  A1Cresult_Norm  \
# 59249               0               0                  0               0
# 78837               1               1                  0               0
# 53312               0               1                  0               0
#
#        diag_3_digestive  discharge_disposition_unknown  A1Cresult_>7  \
# 59249                 0                              0             0
# 78837                 0                              0             0
# 53312                 0                              0             0
#
#        diag_2_skin  admission_source_id_8  diag_3_other  \
# 59249            0                      0             0
# 78837            0                      0             0
# 53312            0                      0             0
#
#        discharge_disposition_hospital  race_Other  diag_1_metabolic  \
# 59249                               0           0                 0
# 78837                               0           0                 0
# 53312                               0           0                 0
#
#        diag_1_other  diag_3_skin  diag_1_infection  diag_1_musculoskeletal  \
# 59249             0            0                 0                       0
# 78837             0            0                 0                       0
# 53312             0            0                 0                       0
#
#        diag_2_neoplasm  diag_1_neoplasm  admission_source_id_4  \
# 59249                1                1                      0
# 78837                0                0                      0
# 53312                0                0                      0
#
#        discharge_disposition_hospice  diag_2_blooddis  diag_1_mentaldis  \
# 59249                              0                0                 0
# 78837                              0                0                 0
# 53312                              0                0                 0
#
#        diag_2_infection  diag_1_skin  race_Hispanic  diag_3_neoplasm  \
# 59249                 0            0              0                0
# 78837                 0            0              0                0
# 53312                 0            0              0                0
#
#        diag_2_musculoskeletal  diag_1_blooddis  admission_source_id_6  age_3  \
# 59249                       0                0                      0      0
# 78837                       0                0                      0      0
# 53312                       0                0                      0      0
#
#        max_glu_serum_>300  max_glu_serum_>200
# 59249                   0                   0
# 78837                   0                   0
# 53312                   0                   0

# %% [markdown]
# ## 2.4 Assessing feature importance with Akaike/Bayesian Information Criterion (AIC/BIC)

# %% [markdown]
# The below code will impliment a series of stepwise actions, sequentially identifying feature for removal that correspond to the greatest relative decrease in the AIC metric. A high decrease in the AIC value designates that the feature in question has realtively low impact on predictions, and therefore might be a good choice for removal.

# %%
selected_features = list(FI_dataset.columns)
max_iterations = 20  # Set a maximum number of iterations

for iteration in range(1, max_iterations + 1):
    # Add a constant term to the features (required for statsmodels)
    X = sm.add_constant(FI_dataset[selected_features])
    
    # Fit the ordinary least squares (OLS) model
    model = sm.OLS(y, X).fit()
    
    # Get AIC value
    current_aic = model.aic
    
    # Identify the least significant feature
    least_significant_feature = model.pvalues[1:].idxmax()  # Exclude 'const' term
    
    # Remove the least significant feature
    selected_features.remove(least_significant_feature)
    
    # Check if only 'const' term is left
    if len(selected_features) == 0:
        break
    
    # Fit the model again after removing the feature
    model = sm.OLS(y, sm.add_constant(FI_dataset[selected_features])).fit()
    
    # Calculate the new AIC
    new_aic = model.aic
    
    # Print progress
    print(f"Iteration {iteration}: AIC = {new_aic}, Removed Feature: {least_significant_feature}")
    
    # Check for convergence based on a change in AIC
    if abs(new_aic - current_aic) < 1e-4:
        print("Converged.")
        break

# Display the selected features
print("\nSelected Features:", selected_features)
# Out:
# Iteration 1: AIC = 50121.45041946409, Removed Feature: age_9
# Iteration 2: AIC = 50119.45197114616, Removed Feature: change
# Iteration 3: AIC = 50117.453896325605, Removed Feature: race_Hispanic
# Iteration 4: AIC = 50115.45949997238, Removed Feature: diag_1_blooddis
# Iteration 5: AIC = 50113.46554896209, Removed Feature: admission_source_id_6
# Iteration 6: AIC = 50111.532109878346, Removed Feature: medication_insulin
# Iteration 7: AIC = 50109.76871432981, Removed Feature: time_in_hospital
# Iteration 8: AIC = 50108.06526256996, Removed Feature: diag_1_metabolic
# Iteration 9: AIC = 50106.38562072988, Removed Feature: admission_type_id_5
# Iteration 10: AIC = 50104.89057352749, Removed Feature: diag_2_musculoskeletal
# Iteration 11: AIC = 50103.449893821584, Removed Feature: diag_2_urogenital
# Iteration 12: AIC = 50102.12515987831, Removed Feature: diag_3_skin
# Iteration 13: AIC = 50100.94775154319, Removed Feature: diag_2_infection
# Iteration 14: AIC = 50099.78553381152, Removed Feature: medication_glyburide
# Iteration 15: AIC = 50098.81252772629, Removed Feature: diag_1_mentaldis
# Iteration 16: AIC = 50097.903158598, Removed Feature: diag_3_injury
# Iteration 17: AIC = 50097.07338430843, Removed Feature: diag_1_Nothing
# Iteration 18: AIC = 50096.181282966165, Removed Feature: age_5
# Iteration 19: AIC = 50095.382149451994, Removed Feature: diag_3_metabolic
# Iteration 20: AIC = 50094.94845176535, Removed Feature: admission_source_id_4
#
# Selected Features: ['num_lab_procedures', 'num_medications', 'number_inpatient', 'num_procedures', 'number_diagnoses', 'number_outpatient', 'number_emergency', 'gender_Male', 'admission_source_id_1', 'diag_3_Nothing', 'diag_2_Nothing', 'diag_2_respiratory', 'admission_type_id_3', 'age_6', 'diag_3_respiratory', 'medication_metformin', 'discharge_disposition_hhealth', 'diag_1_digestive', 'diag_1_respiratory', 'diag_1_injury', 'discharge_disposition_outpatient', 'diag_3_urogenital', 'discharge_disposition_nursing', 'any_medication', 'diag_1_urogenital', 'A1Cresult_Norm', 'diag_3_digestive', 'discharge_disposition_unknown', 'A1Cresult_>7', 'diag_2_skin', 'admission_source_id_8', 'diag_3_other', 'discharge_disposition_hospital', 'race_Other', 'diag_1_other', 'diag_1_infection', 'diag_1_musculoskeletal', 'diag_2_neoplasm', 'diag_1_neoplasm', 'discharge_disposition_hospice', 'diag_2_blooddis', 'diag_1_skin', 'diag_3_neoplasm', 'age_3', 'max_glu_serum_>300', 'max_glu_serum_>200']

# %%
import statsmodels.api as sm

selected_features = list(FI_dataset.columns)
max_iterations = 20  # Set a maximum number of iterations

for iteration in range(1, max_iterations + 1):
    # Add a constant term to the features (required for statsmodels)
    X = sm.add_constant(FI_dataset[selected_features])
    
    # Fit the ordinary least squares (OLS) model
    model = sm.OLS(y, X).fit()
    
    # Get BIC value
    current_bic = model.bic
    
    # Identify the least significant feature
    least_significant_feature = model.pvalues[1:].idxmax()  # Exclude 'const' term
    
    # Remove the least significant feature
    selected_features.remove(least_significant_feature)
    
    # Check if only 'const' term is left
    if len(selected_features) == 0:
        break
    
    # Fit the model again after removing the feature
    model = sm.OLS(y, sm.add_constant(FI_dataset[selected_features])).fit()
    
    # Calculate the new BIC
    new_bic = model.bic
    
    # Print progress
    print(f"Iteration {iteration}: BIC = {new_bic}, Removed Feature: {least_significant_feature}")
    
    # Check for convergence based on a change in BIC
    if abs(new_bic - current_bic) < 1e-4:
        print("Converged.")
        break

# Display the selected features
print("\nSelected Features:", selected_features)
# Out:
# Iteration 1: BIC = 50749.37869729789, Removed Feature: age_9
# Iteration 2: BIC = 50737.8661841643, Removed Feature: change
# Iteration 3: BIC = 50726.35404452808, Removed Feature: race_Hispanic
# Iteration 4: BIC = 50714.84558335919, Removed Feature: diag_1_blooddis
# Iteration 5: BIC = 50703.33756753324, Removed Feature: admission_source_id_6
# Iteration 6: BIC = 50691.89006363383, Removed Feature: medication_insulin
# Iteration 7: BIC = 50680.61260326963, Removed Feature: time_in_hospital
# Iteration 8: BIC = 50669.395086694116, Removed Feature: diag_1_metabolic
# Iteration 9: BIC = 50658.20138003837, Removed Feature: admission_type_id_5
# Iteration 10: BIC = 50647.19226802032, Removed Feature: diag_2_musculoskeletal
# Iteration 11: BIC = 50636.23752349875, Removed Feature: diag_2_urogenital
# Iteration 12: BIC = 50625.39872473981, Removed Feature: diag_3_skin
# Iteration 13: BIC = 50614.70725158903, Removed Feature: diag_2_infection
# Iteration 14: BIC = 50604.03096904169, Removed Feature: medication_glyburide
# Iteration 15: BIC = 50593.5438981408, Removed Feature: diag_1_mentaldis
# Iteration 16: BIC = 50583.12046419684, Removed Feature: diag_3_injury
# Iteration 17: BIC = 50572.77662509161, Removed Feature: diag_1_Nothing
# Iteration 18: BIC = 50562.370458933685, Removed Feature: age_5
# Iteration 19: BIC = 50552.05726060385, Removed Feature: diag_3_metabolic
# Iteration 20: BIC = 50542.10949810154, Removed Feature: admission_source_id_4
#
# Selected Features: ['num_lab_procedures', 'num_medications', 'number_inpatient', 'num_procedures', 'number_diagnoses', 'number_outpatient', 'number_emergency', 'gender_Male', 'admission_source_id_1', 'diag_3_Nothing', 'diag_2_Nothing', 'diag_2_respiratory', 'admission_type_id_3', 'age_6', 'diag_3_respiratory', 'medication_metformin', 'discharge_disposition_hhealth', 'diag_1_digestive', 'diag_1_respiratory', 'diag_1_injury', 'discharge_disposition_outpatient', 'diag_3_urogenital', 'discharge_disposition_nursing', 'any_medication', 'diag_1_urogenital', 'A1Cresult_Norm', 'diag_3_digestive', 'discharge_disposition_unknown', 'A1Cresult_>7', 'diag_2_skin', 'admission_source_id_8', 'diag_3_other', 'discharge_disposition_hospital', 'race_Other', 'diag_1_other', 'diag_1_infection', 'diag_1_musculoskeletal', 'diag_2_neoplasm', 'diag_1_neoplasm', 'discharge_disposition_hospice', 'diag_2_blooddis', 'diag_1_skin', 'diag_3_neoplasm', 'age_3', 'max_glu_serum_>300', 'max_glu_serum_>200']

# %% [markdown]
# Both AIC and BIC recommend dropping many of the same variables. However, some of these variables  have relatively high correlation/feature importance relative to others on the list (e.g. change in medication, time in hospital).
#
# Therefore, rather than dropping the top values, we will selectively choose 5 variables from this list that are near the top, but do not demonstrate a standout relationship with the outcome variable.

# %%
AIC_BIC_reduced = FI_dataset.drop(['diag_1_blooddis', 'admission_source_id_6', 'diag_1_metabolic', 'admission_type_id_5', 'diag_2_musculoskeletal'], axis=1)

print(AIC_BIC_reduced.shape)
AIC_BIC_reduced.sample(3)
# Out:
# (100114, 61)
#        num_lab_procedures  num_medications  time_in_hospital  \
# 76711                   2                8                 1
# 54799                  36                3                10
# 23696                  66               15                 6
#
#        number_inpatient  num_procedures  number_diagnoses  number_outpatient  \
# 76711                 9               1                 6                  0
# 54799                 0               2                 9                  0
# 23696                 0               0                 9                  0
#
#        number_emergency  gender_Male  admission_source_id_1  change  \
# 76711                 0            1                      0       0
# 54799                 0            1                      0       0
# 23696                 0            0                      0       0
#
#        diag_3_Nothing  age_9  diag_2_Nothing  medication_insulin  \
# 76711               1      0               0                   0
# 54799               0      1               0                   1
# 23696               0      0               0                   1
#
#        diag_2_respiratory  admission_type_id_3  diag_2_urogenital  age_6  \
# 76711                   0                    0                  0      1
# 54799                   1                    0                  0      0
# 23696                   0                    0                  0      0
#
#        medication_glyburide  diag_3_respiratory  diag_3_metabolic  \
# 76711                     0                   0                 0
# 54799                     0                   0                 0
# 23696                     0                   0                 1
#
#        medication_metformin  discharge_disposition_hhealth  diag_1_digestive  \
# 76711                     0                              0                 1
# 54799                     0                              0                 0
# 23696                     0                              0                 0
#
#        diag_1_respiratory  diag_1_injury  age_5  \
# 76711                   0              0      0
# 54799                   1              0      0
# 23696                   0              0      1
#
#        discharge_disposition_outpatient  diag_3_urogenital  \
# 76711                                 0                  0
# 54799                                 0                  0
# 23696                                 0                  0
#
#        discharge_disposition_nursing  diag_3_injury  diag_1_Nothing  \
# 76711                              0              0               0
# 54799                              0              0               0
# 23696                              0              0               1
#
#        any_medication  diag_1_urogenital  A1Cresult_Norm  diag_3_digestive  \
# 76711               0                  0               0                 0
# 54799               1                  0               0                 1
# 23696               1                  0               0                 0
#
#        discharge_disposition_unknown  A1Cresult_>7  diag_2_skin  \
# 76711                              0             0            0
# 54799                              0             0            0
# 23696                              0             0            0
#
#        admission_source_id_8  diag_3_other  discharge_disposition_hospital  \
# 76711                      0             0                               0
# 54799                      0             0                               0
# 23696                      0             0                               0
#
#        race_Other  diag_1_other  diag_3_skin  diag_1_infection  \
# 76711           0             0            0                 0
# 54799           0             0            0                 0
# 23696           0             0            0                 0
#
#        diag_1_musculoskeletal  diag_2_neoplasm  diag_1_neoplasm  \
# 76711                       0                0                0
# 54799                       0                0                0
# 23696                       0                0                0
#
#        admission_source_id_4  discharge_disposition_hospice  diag_2_blooddis  \
# 76711                      0                              0                0
# 54799                      0                              1                0
# 23696                      0                              0                0
#
#        diag_1_mentaldis  diag_2_infection  diag_1_skin  race_Hispanic  \
# 76711                 0                 0            0              1
# 54799                 0                 0            0              0
# 23696                 0                 0            0              0
#
#        diag_3_neoplasm  age_3  max_glu_serum_>300  max_glu_serum_>200
# 76711                0      0                   0                   0
# 54799                0      0                   0                   0
# 23696                0      0                   0                   0

# %% [markdown]
# ## 2.5 Assessing feature variability with Principal Component Analysis (PCA)

# %% [markdown]
# PCA is a technique to reduce the dimensionality of a dataset, while maintaining as much of the data's variance as as possible. We will fit a PCA model, and then assess variance score for each feature. Features with low variance scores represent candidates for removal from the model.

# %% [markdown]
# #### Standardizing our features

# %%
scaler = StandardScaler()
diabetes_scaled = scaler.fit_transform(AIC_BIC_reduced)

# %% [markdown]
# #### Fitting the PCA to our data

# %%
# Perform PCA considering the target variable
pca = PCA(n_components=AIC_BIC_reduced.shape[1])  # Use all features initially
pca.fit_transform(AIC_BIC_reduced)
# Out:
# array([[-3.21357661e+01,  1.33532645e+00, -1.02267207e+00, ...,
#         -3.25866086e-02,  3.63990402e-02, -2.66300792e-03],
#        [ 2.68320249e+01,  9.69509192e+00,  5.62068164e+00, ...,
#         -2.58094460e-02,  1.95709802e-03, -8.24111830e-03],
#        [ 4.41927789e+00,  1.29621911e+00,  4.39065164e+00, ...,
#          2.36685169e-02,  2.57625691e-02, -1.73481457e-02],
#        ...,
#        [-9.50791414e+00,  3.65319681e+00,  8.42307553e-01, ...,
#          5.52127406e-02, -1.93517293e-02, -1.47793568e-02],
#        [ 3.01584872e+00,  5.64943971e+00,  4.81942717e+00, ...,
#         -4.26342759e-02, -2.79282670e-03, -2.00809684e-02],
#        [-3.12112938e+01, -8.05084181e+00,  4.94891013e+00, ...,
#          5.20392978e-02, -6.50812152e-03, -3.85866908e-03]])

# %% [markdown]
# #### Compiling variance scores from PCA model

# %%
# Calculate feature variance based on PCA components
pca_feature_variances = abs(pca.components_)

# Calculate cumulative sum of feature variances
pca_cumulative_variances = pca_feature_variances.sum(axis=0)

# %% [markdown]
# Creating a dataset detailing feature names and variance scores

# %%
#Compiling elements into dataset
pca_features = list(zip(AIC_BIC_reduced.columns, pca_cumulative_variances))
#Assigning column names
pca_features_df = pd.DataFrame(pca_features, columns = ["feature", "importance_value"]) 
#Sorting by variance
pca_sorted_df = pca_features_df.sort_values(by='importance_value', ascending=False)

print(pca_sorted_df.shape)
# Out:
# (61, 2)

# %%
pca_sorted_df
# Out:
#                              feature  importance_value
# 32                    diag_1_Nothing          4.859158
# 26                     diag_1_injury          4.614685
# 24                  diag_1_digestive          4.556351
# 47            diag_1_musculoskeletal          4.538388
# 31                     diag_3_injury          4.433842
# 49                   diag_1_neoplasm          4.353279
# 15                diag_2_respiratory          4.327196
# 30     discharge_disposition_nursing          4.268294
# 39                       diag_2_skin          4.261847
# 29                 diag_3_urogenital          4.229720
# 13                    diag_2_Nothing          4.229501
# 17                 diag_2_urogenital          4.172346
# 36                  diag_3_digestive          4.153958
# 45                       diag_3_skin          4.132259
# 21                  diag_3_metabolic          4.122018
# 48                   diag_2_neoplasm          4.057562
# 34                 diag_1_urogenital          4.054590
# 25                diag_1_respiratory          3.979736
# 55                       diag_1_skin          3.851816
# 9              admission_source_id_1          3.746295
# 50             admission_source_id_4          3.724131
# 20                diag_3_respiratory          3.695797
# 23     discharge_disposition_hhealth          3.694140
# 46                  diag_1_infection          3.692531
# 12                             age_9          3.655731
# 53                  diag_1_mentaldis          3.648836
# 27                             age_5          3.636664
# 16               admission_type_id_3          3.589478
# 11                    diag_3_Nothing          3.475821
# 22              medication_metformin          3.432438
# 19              medication_glyburide          3.386038
# 18                             age_6          3.381743
# 52                   diag_2_blooddis          3.338223
# 28  discharge_disposition_outpatient          3.309797
# 51     discharge_disposition_hospice          3.262102
# 44                      diag_1_other          3.237536
# 57                   diag_3_neoplasm          3.227239
# 37     discharge_disposition_unknown          3.205726
# 14                medication_insulin          3.205217
# 41                      diag_3_other          3.172085
# 33                    any_medication          3.117207
# 54                  diag_2_infection          3.022876
# 40             admission_source_id_8          3.015472
# 42    discharge_disposition_hospital          2.962916
# 10                            change          2.881506
# 35                    A1Cresult_Norm          2.692423
# 58                             age_3          2.585051
# 38                      A1Cresult_>7          2.566818
# 3                   number_inpatient          2.230243
# 60                max_glu_serum_>200          2.154000
# 43                        race_Other          2.152923
# 56                     race_Hispanic          2.028405
# 5                   number_diagnoses          1.993990
# 8                        gender_Male          1.946622
# 4                     num_procedures          1.934442
# 59                max_glu_serum_>300          1.912002
# 6                  number_outpatient          1.841061
# 7                   number_emergency          1.816071
# 2                   time_in_hospital          1.623915
# 1                    num_medications          1.522222
# 0                 num_lab_procedures          1.202216

# %% [markdown]
# As we can see, some of the lowest variance features (which we might consider dropping, as low variance features tend not to be of much predictive value), are the variables that also correlate most highly with out outcome variable (e.g. num_lab_procedures, num_medications). Therefore, we will opt to keep all of our variables as of this point. However, it is good to know that there are are few if any irrelevant and low-variance features remaining in our dataset.

# %% [markdown]
# ## 2.6 Splitting and exporting engineered datasets to s3 for machine learning

# %% [markdown]
# Here we filter our original dataset by the columns we have selected to retain (i.e., those remaining after steps 2.2 through 2.4).

# %%
reduced_dataset = pd.concat([diabetes['readmitted'], AIC_BIC_reduced], axis=1)
print(reduced_dataset.shape)
reduced_dataset.sample()
# Out:
# (100114, 62)
#        readmitted  num_lab_procedures  num_medications  time_in_hospital  \
# 86792           0                  47                7                 3
#
#        number_inpatient  num_procedures  number_diagnoses  number_outpatient  \
# 86792                 0               0                 9                  0
#
#        number_emergency  gender_Male  admission_source_id_1  change  \
# 86792                 0            1                      1       0
#
#        diag_3_Nothing  age_9  diag_2_Nothing  medication_insulin  \
# 86792               0      1               0                   0
#
#        diag_2_respiratory  admission_type_id_3  diag_2_urogenital  age_6  \
# 86792                   0                    1                  0      0
#
#        medication_glyburide  diag_3_respiratory  diag_3_metabolic  \
# 86792                     0                   0                 1
#
#        medication_metformin  discharge_disposition_hhealth  diag_1_digestive  \
# 86792                     0                              0                 0
#
#        diag_1_respiratory  diag_1_injury  age_5  \
# 86792                   0              0      0
#
#        discharge_disposition_outpatient  diag_3_urogenital  \
# 86792                                 0                  0
#
#        discharge_disposition_nursing  diag_3_injury  diag_1_Nothing  \
# 86792                              1              0               0
#
#        any_medication  diag_1_urogenital  A1Cresult_Norm  diag_3_digestive  \
# 86792               1                  0               0                 0
#
#        discharge_disposition_unknown  A1Cresult_>7  diag_2_skin  \
# 86792                              0             0            0
#
#        admission_source_id_8  diag_3_other  discharge_disposition_hospital  \
# 86792                      0             0                               0
#
#        race_Other  diag_1_other  diag_3_skin  diag_1_infection  \
# 86792           0             0            0                 0
#
#        diag_1_musculoskeletal  diag_2_neoplasm  diag_1_neoplasm  \
# 86792                       0                0                0
#
#        admission_source_id_4  discharge_disposition_hospice  diag_2_blooddis  \
# 86792                      0                              0                0
#
#        diag_1_mentaldis  diag_2_infection  diag_1_skin  race_Hispanic  \
# 86792                 0                 0            0              0
#
#        diag_3_neoplasm  age_3  max_glu_serum_>300  max_glu_serum_>200
# 86792                0      0                   0                   0

# %% [markdown]
# #### Now, we will split this data into a 85% train/validation dataset, and a residual 15% holdout test dataset for our final evaluation.

# %%
# Set a seed for reproducibility
np.random.seed(42)

# Create an array of random indices
random_indices = np.random.permutation(reduced_dataset.index)

# Determine the size of the training set (e.g., 85%)
train_size = int(0.85 * len(reduced_dataset))

# Assign train/test labels based on the random indices
reduced_dataset['split'] = 'test'
reduced_dataset.loc[random_indices[:train_size], 'split'] = 'train'

print(reduced_dataset.shape)
reduced_dataset.sample(3)
# Out:
# (100114, 63)
#        readmitted  num_lab_procedures  num_medications  time_in_hospital  \
# 74186           0                  32               19                 1
# 55145           0                   2               13                 7
# 87162           0                  72               29                 6
#
#        number_inpatient  num_procedures  number_diagnoses  number_outpatient  \
# 74186                 1               6                 5                  0
# 55145                 1               1                 9                  0
# 87162                 0               3                 9                  0
#
#        number_emergency  gender_Male  admission_source_id_1  change  \
# 74186                 0            0                      1       1
# 55145                 0            1                      1       0
# 87162                 0            1                      0       1
#
#        diag_3_Nothing  age_9  diag_2_Nothing  medication_insulin  \
# 74186               0      0               1                   0
# 55145               0      1               0                   0
# 87162               0      0               0                   1
#
#        diag_2_respiratory  admission_type_id_3  diag_2_urogenital  age_6  \
# 74186                   0                    1                  0      1
# 55145                   0                    0                  1      0
# 87162                   0                    0                  0      1
#
#        medication_glyburide  diag_3_respiratory  diag_3_metabolic  \
# 74186                     0                   0                 0
# 55145                     0                   0                 0
# 87162                     0                   0                 1
#
#        medication_metformin  discharge_disposition_hhealth  diag_1_digestive  \
# 74186                     0                              0                 0
# 55145                     0                              1                 0
# 87162                     1                              0                 0
#
#        diag_1_respiratory  diag_1_injury  age_5  \
# 74186                   0              0      0
# 55145                   0              1      0
# 87162                   0              0      0
#
#        discharge_disposition_outpatient  diag_3_urogenital  \
# 74186                                 0                  0
# 55145                                 0                  0
# 87162                                 0                  0
#
#        discharge_disposition_nursing  diag_3_injury  diag_1_Nothing  \
# 74186                              0              0               0
# 55145                              0              1               0
# 87162                              0              0               0
#
#        any_medication  diag_1_urogenital  A1Cresult_Norm  diag_3_digestive  \
# 74186               1                  0               0                 0
# 55145               1                  0               0                 0
# 87162               1                  0               0                 0
#
#        discharge_disposition_unknown  A1Cresult_>7  diag_2_skin  \
# 74186                              0             0            0
# 55145                              0             0            0
# 87162                              0             1            0
#
#        admission_source_id_8  diag_3_other  discharge_disposition_hospital  \
# 74186                      0             0                               0
# 55145                      0             0                               0
# 87162                      0             0                               0
#
#        race_Other  diag_1_other  diag_3_skin  diag_1_infection  \
# 74186           0             0            0                 0
# 55145           0             0            0                 0
# 87162           0             0            0                 1
#
#        diag_1_musculoskeletal  diag_2_neoplasm  diag_1_neoplasm  \
# 74186                       0                0                0
# 55145                       0                0                0
# 87162                       0                0                0
#
#        admission_source_id_4  discharge_disposition_hospice  diag_2_blooddis  \
# 74186                      0                              0                0
# 55145                      0                              0                0
# 87162                      0                              0                0
#
#        diag_1_mentaldis  diag_2_infection  diag_1_skin  race_Hispanic  \
# 74186                 0                 0            0              0
# 55145                 0                 0            0              0
# 87162                 0                 0            0              0
#
#        diag_3_neoplasm  age_3  max_glu_serum_>300  max_glu_serum_>200  split
# 74186                0      0                   0                   0  train
# 55145                0      0                   0                   0  train
# 87162                0      0                   0                   0  train

# %% [markdown]
# #### Splitting the datasets and removing the "split" column.

# %%
reduced_dataset_train = reduced_dataset.loc[reduced_dataset['split'] == "train",].drop(["split"], axis=1)
reduced_dataset_test = reduced_dataset.loc[reduced_dataset['split'] == "test",].drop(["split"], axis=1)

# %%
print(reduced_dataset_test.shape)
print(reduced_dataset_train.shape)
# Out:
# (15018, 62)
# (85096, 62)

# %%
reduced_dataset_train.sample()
# Out:
#        readmitted  num_lab_procedures  num_medications  time_in_hospital  \
# 40790           0                  62               18                 2
#
#        number_inpatient  num_procedures  number_diagnoses  number_outpatient  \
# 40790                 0               0                 5                  0
#
#        number_emergency  gender_Male  admission_source_id_1  change  \
# 40790                 0            0                      0       0
#
#        diag_3_Nothing  age_9  diag_2_Nothing  medication_insulin  \
# 40790               0      1               0                   1
#
#        diag_2_respiratory  admission_type_id_3  diag_2_urogenital  age_6  \
# 40790                   1                    0                  0      0
#
#        medication_glyburide  diag_3_respiratory  diag_3_metabolic  \
# 40790                     0                   0                 0
#
#        medication_metformin  discharge_disposition_hhealth  diag_1_digestive  \
# 40790                     0                              0                 0
#
#        diag_1_respiratory  diag_1_injury  age_5  \
# 40790                   0              0      0
#
#        discharge_disposition_outpatient  diag_3_urogenital  \
# 40790                                 0                  0
#
#        discharge_disposition_nursing  diag_3_injury  diag_1_Nothing  \
# 40790                              1              0               0
#
#        any_medication  diag_1_urogenital  A1Cresult_Norm  diag_3_digestive  \
# 40790               1                  0               1                 0
#
#        discharge_disposition_unknown  A1Cresult_>7  diag_2_skin  \
# 40790                              0             0            0
#
#        admission_source_id_8  diag_3_other  discharge_disposition_hospital  \
# 40790                      0             0                               0
#
#        race_Other  diag_1_other  diag_3_skin  diag_1_infection  \
# 40790           0             0            0                 0
#
#        diag_1_musculoskeletal  diag_2_neoplasm  diag_1_neoplasm  \
# 40790                       0                0                0
#
#        admission_source_id_4  discharge_disposition_hospice  diag_2_blooddis  \
# 40790                      0                              0                0
#
#        diag_1_mentaldis  diag_2_infection  diag_1_skin  race_Hispanic  \
# 40790                 0                 0            0              0
#
#        diag_3_neoplasm  age_3  max_glu_serum_>300  max_glu_serum_>200
# 40790                0      0                   0                   0

# %%
reduced_dataset_test.sample()
# Out:
#        readmitted  num_lab_procedures  num_medications  time_in_hospital  \
# 44472           0                  43               17                 4
#
#        number_inpatient  num_procedures  number_diagnoses  number_outpatient  \
# 44472                 0               0                 5                  0
#
#        number_emergency  gender_Male  admission_source_id_1  change  \
# 44472                 0            0                      0       0
#
#        diag_3_Nothing  age_9  diag_2_Nothing  medication_insulin  \
# 44472               0      0               0                   0
#
#        diag_2_respiratory  admission_type_id_3  diag_2_urogenital  age_6  \
# 44472                   1                    0                  0      0
#
#        medication_glyburide  diag_3_respiratory  diag_3_metabolic  \
# 44472                     0                   0                 0
#
#        medication_metformin  discharge_disposition_hhealth  diag_1_digestive  \
# 44472                     0                              0                 0
#
#        diag_1_respiratory  diag_1_injury  age_5  \
# 44472                   0              0      1
#
#        discharge_disposition_outpatient  diag_3_urogenital  \
# 44472                                 0                  0
#
#        discharge_disposition_nursing  diag_3_injury  diag_1_Nothing  \
# 44472                              0              0               0
#
#        any_medication  diag_1_urogenital  A1Cresult_Norm  diag_3_digestive  \
# 44472               1                  0               0                 0
#
#        discharge_disposition_unknown  A1Cresult_>7  diag_2_skin  \
# 44472                              0             0            0
#
#        admission_source_id_8  diag_3_other  discharge_disposition_hospital  \
# 44472                      0             0                               0
#
#        race_Other  diag_1_other  diag_3_skin  diag_1_infection  \
# 44472           0             0            0                 1
#
#        diag_1_musculoskeletal  diag_2_neoplasm  diag_1_neoplasm  \
# 44472                       0                0                0
#
#        admission_source_id_4  discharge_disposition_hospice  diag_2_blooddis  \
# 44472                      0                              0                0
#
#        diag_1_mentaldis  diag_2_infection  diag_1_skin  race_Hispanic  \
# 44472                 0                 0            0              0
#
#        diag_3_neoplasm  age_3  max_glu_serum_>300  max_glu_serum_>200
# 44472                0      0                   0                   0

# %% [markdown]
# Everything looks good, so now we can export 4 versions of out dataset (respective train, and test datasets for model development, and then a full version for an operational assessment of the model -- a version both with and without headers).

# %%
def Export_Processed_CSV(bucket, processed_data_folder, local_file_name, S3_file_name, header_presence):
        
    '''Exports a dataframe into CSV format, and sends to a specified S3 bucket location
    
    Arguments 
    --------- 
    bucket: A list of the columns (i.e. the 3 diagnosis columns) to be updated
    processed_data_folder: the relevant subfolder within the main bucket
    local_file_name: The name of the dataframe within the notebook
    S3_file_name: The name of the file uppn export (with .csv extension included)
    header_presence: whether or not a header will be present within the exported csv
    
    Return
    ---------
    Exports a csv file to a specified S3 location'''
    
    local_file_name.to_csv(S3_file_name, index=False, header=header_presence)
    boto3.Session().resource('s3').Bucket(bucket).Object('{}/{}'.format(processed_data_folder, S3_file_name)).upload_file(S3_file_name)

# %% [markdown]
# #### Exporting CSVs

# %%
Export_Processed_CSV(bucket, cleaned_diabetes, reduced_dataset_train, reduced_dimensions_diabetes_train, True)
Export_Processed_CSV(bucket, cleaned_diabetes, reduced_dataset_test, reduced_dimensions_diabetes_test, True)

# %% [markdown]
# Please continue to the third script in this repository: 3. Model_Tuning_Deployment_Predictions
